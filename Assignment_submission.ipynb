# %% [markdown]
# <a href="https://colab.research.google.com/github/adityaverma123457/EDA-on-sales-data-/blob/main/Assignment_submission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class random_gen:
  def __init__(self,n):
    #Xo = 5
    self.n = n

  def Random(self,decimal=None):
    import os
    import numpy as np
    #Xo = 5
    c = 3
    a = 3
    m = 50
    size = 3
    randomNums = [0] * (self.n)
    #randomNums[0] = Xo
    if decimal is None :
      decimal = 1
      l = 1
    else :
      l = 100000

    for i in range(1, self.n):
      result = os.urandom(size)
      # Follow the linear congruential method
      randomNums[i] = round((int.from_bytes(result,'little')/m + 1)/l , decimal)
    return randomNums

  def visualise(self):
    import matplotlib.pyplot as plt
    import seaborn as sns
    import numpy as np
    import math
    X , Y = np.array(random_gen(self.n).Random(decimal=3)),np.array(random_gen(self.n).Random(decimal=3))

    plt.scatter(X,Y,color='b')
    plt.hlines(y=1,xmin=0,xmax=1)
    plt.vlines(x=1,ymin=0,ymax=1)
    plt.plot([1],[1], marker="o", markersize=7, markeredgecolor="red", markerfacecolor="black")

    plt.ylim((0,2))
    plt.xlim((0,2))
    plt.tight_layout()
    return X , Y 

  def pie(self):
    circle = []
    X , Y = random_gen(self.n).visualise()
    cnt=0
    for i in list(zip(X,Y)):
      x , y = (i[0] - 1) , (i[1] - 1)
      dist = math.sqrt(x**2 + y**2)
      if dist <=1:
        circle.append(i)
      elif (dist <= math.sqrt(2)) & (dist > 1):
        cnt+=1
    a , b = list(zip(*circle))
    plt.scatter(a,b,color='r')
    plt.show()
    Pi = 4 * len(circle)/(len(circle)+cnt)  # 4 * (number of points inside the circle) / (Number of points points in the square)
    print(f"Estimated value of Pie is : {Pi}")
    return Pi

print(random_gen(100000).Random(decimal=3))
#random_gen(10000).visualise()
random_gen(10000).pie()
# Out:
# [0, 1.519, 1.662, 2.787, 0.667, 3.213, 1.492, 3.23, 1.018, 1.791, 1.726, 3.299, 0.901, 2.568, 3.323, 3.295, 2.341, 1.19, 1.208, 3.201, 0.883, 3.094, 3.32, 1.052, 3.309, 1.997, 2.3, 1.061, 0.993, 2.697, 2.143, 0.697, 2.8, 0.561, 1.556, 3.264, 0.615, 2.358, 3.226, 2.805, 2.031, 3.13, 0.431, 0.866, 1.202, 1.996, 0.121, 0.177, 0.6, 2.677, 1.239, 0.322, 3.185, 0.276, 0.757, 2.875, 2.712, 0.897, 1.473, 1.508, 0.82, 2.364, 0.079, 2.659, 2.67, 1.741, 0.216, 0.809, 0.535, 2.115, 3.041, 0.723, 2.693, 2.713, 3.309, 0.589, 1.821, 2.249, 0.35, 1.733, 1.095, 3.339, 1.416, 0.001, 0.795, 0.052, 3.066, 2.911, 2.957, 1.322, 1.39, 1.953, 2.589, 0.612, 1.285, 0.941, 0.899, 2.355, 0.044, 0.652, 1.606, 2.593, 0.605, 0.807, 0.588, 1.096, 2.633, 0.436, 3.131, 2.152, 2.934, 1.645, 1.111, 1.374, 2.657, 0.446, 0.788, 2.043, 2.402, 0.586, 2.938, 0.336, 3.178, 3.354, 0.725, 1.902, 0.908, 1.76, 1.275, 2.149, 2.553, 3.196, 0.908, 2.352, 2.736, 1.151, 0.313, 1.285, 2.387, 0.698, 1.489, 1.457, 2.576, 0.574, 3.178, 1.308, 0.72, 1.327, 0.712, 1.719, 1.238, 2.356, 2.269, 1.595, 2.29, 1.01, 3.116, 0.812, 2.761, 2.777, 1.447, 3.139, 2.06, 0.914, 2.188, 2.724, 1.007, 2.985, 0.261, 2.154, 0.021, 1.161, 3.107, 3.028, 0.857, 0.526, 2.818, 2.411, 3.171, 2.312, 0.078, 0.193, 1.398, 1.312, 3.149, 0.483, 1.438, 0.844, 1.969, 3.016, 0.873, 0.521, 2.126, 0.19, 3.265, 1.805, 2.479, 0.885, 2.816, 3.251, 1.296, 2.626, 0.046, 0.524, 0.